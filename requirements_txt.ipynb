# %% [markdown]
# <a href="https://colab.research.google.com/github/rahna1369/Supply-Chain-AI-Dashboard/blob/main/requirements_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile requirements.txt
# streamlit
# pandas
# numpy
# plotly
# statsmodels
# Out:
# Writing requirements.txt
